# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv("/content/IRIS.csv")
ds

# %% [markdown]
# #### Pandas Basic Commands

# %%
ds.head()

# %%
ds.tail()

# %%
ds.info()

# %%
# Changing Data Types
print("Changing Data Types:")
ds['sepal_length'] = ds['sepal_length'].astype(int)
ds['sepal_width'] = ds['sepal_width'].astype(int)
ds['petal_length'] = ds['petal_length'].astype(int)
ds['petal_width'] = ds['petal_width'].astype(int)

print(ds)

# %%
ds.info()

# %%
ds.shape

# %%
ds.columns

# %%
ds['sepal_length']

# %%
ds.duplicated().sum()
ds = ds.drop_duplicates()

# %%
ds.duplicated().sum()

# %%
ds.isnull().sum()

# %% [markdown]
# #### bar plot

# %%
ds.plot.bar(x = 'sepal_length', y = 'sepal_width')
# Out:
# <Axes: xlabel='sepal_length'>

# %%
ds.plot.bar(x = 'petal_length', y = 'petal_width')
# Out:
# <Axes: xlabel='petal_length'>

# %%
ds.plot.bar(x = 'sepal_length', y = ['sepal_width', 'petal_length', 'petal_width'])
# Out:
# <Axes: xlabel='sepal_length'>

# %%
ds.plot.bar(x="sepal_length", y="petal_length", color=["black"])
# Out:
# <Axes: xlabel='sepal_length'>

# %%
ds.plot.bar(x="sepal_width", y= ['petal_width'],color=["Purple"])
# Out:
# <Axes: xlabel='sepal_width'>

# %%
ds.plot.barh(x="petal_length", y= ["sepal_width"],color=[ "Green"])
# Out:
# <Axes: ylabel='petal_length'>

# %%
ds.plot.bar(x="sepal_length", y= ["sepal_width",'petal_length','petal_width'],color=["Pink","olive", "blue"], layout = (2,3), subplots= True )
# Out:
# array([[<Axes: title={'center': 'sepal_width'}, xlabel='sepal_length'>,
#         <Axes: title={'center': 'petal_length'}, xlabel='sepal_length'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length'>, <Axes: xlabel='sepal_length'>,
#         <Axes: xlabel='sepal_length'>]], dtype=object)

# %% [markdown]
# #### Scatter Plot

# %%
ds.plot.scatter(x="petal_length", y= "sepal_width",color=["Purple"])
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_width'>

# %%
ds.plot(x="sepal_width", y= ["petal_width"],color=["Purple"], linestyle="--" ,linewidth=3 )
# Out:
# <Axes: xlabel='sepal_width'>

# %%
ds.plot(x="sepal_width", y= ["petal_width"],color=["Purple"], linestyle="-." ,linewidth=3 )
# Out:
# <Axes: xlabel='sepal_width'>

# %%
ds.plot(x = 'sepal_length', y = ['sepal_width'],  linestyle=":" ,linewidth=4 )
# Out:
# <Axes: xlabel='sepal_length'>

# %%
ds.plot(x = 'sepal_length', y = ['sepal_width'], linestyle=":" ,linewidth=4 ,markerfacecolor="Blue" ,markersize="15" ,marker="*")
# Out:
# <Axes: xlabel='sepal_length'>

# %% [markdown]
# #### ploting with label and title

# %%
ds.plot(x="sepal_length", y= ["sepal_width"],color=["Green"], linestyle=":" ,linewidth=4 ,markerfacecolor="black" ,markersize="15" ,marker="*")
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.title("sepal_length vs sepal_width")
plt.show()

# %% [markdown]
# #### Normaling data and Countplot

# %%
ds.species.value_counts(normalize = True)
# Out:
# Iris-setosa        0.333333
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# Name: species, dtype: float64

# %%
#countplot
sns.countplot(x = 'species', data = ds)
plt.xlabel('species')
plt.ylabel('count')
plt.title('Distribution of Iris species')
plt.show()

# %%
plt.figure(figsize = (10,3))
sns.countplot(x = 'sepal_length', data = ds)
plt.xlabel('Sepal_length')
plt.ylabel('Count')
plt.title('Distribution of Sepal Length')
plt.show()

# %%
plt.figure(figsize = (10,3))
sns.countplot(x = 'sepal_width', data = ds)
plt.xlabel('sepal_width')
plt.ylabel('Count')
plt.title('Distribution of sepal_width')
plt.show()

# %%
plt.figure(figsize = (20,5))
sns.countplot(x = 'petal_length', data = ds)
plt.xlabel('petal_length')
plt.ylabel('Count')
plt.title('Distribution of petal_length')
plt.show()

# %%
plt.figure(figsize = (20,3))
sns.countplot(x = 'petal_width', data = ds)
plt.xlabel('petal_width')
plt.ylabel('Count')
plt.title('Distribution of petal_width')
plt.show()

# %% [markdown]
# ####boxplot

# %%
# Boxplot
sns.boxplot(x = 'species',y = 'sepal_length', data = ds)
plt.xlabel('Species')
plt.ylabel('Sepal_length')
plt.title('boxplot of sepal length by iris species')
plt.show()

# %% [markdown]
# ####pairplot

# %%
#pairplot
sns.pairplot(ds, hue = 'species')
plt.title("Pairplot of Iris Dataset")
plt.show()

# %%
ds.corr()
# Out:
# <ipython-input-8-31b754434382>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ds.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ####correlation heatmap

# %%
# correlation heatmap
correlation_matrix = ds.corr()
sns.heatmap(correlation_matrix, annot = True, cmap = 'Pastel1' )
plt.title('correlation matrix of iris Dataset')
plt.show()
# Out:
# <ipython-input-9-1d93298f6ad3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = ds.corr()
